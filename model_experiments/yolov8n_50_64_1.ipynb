# %%
# !pip install ultralytics
# !pip install wandb
# !pip install roboflow
# Out:
# ...
#   Obtaining dependency information for ultralytics from https://files.pythonhosted.org/packages/bd/0c/9a33eec7c8d66a29528994d0cab77f79844c0b3f5258b68481385a1540f3/ultralytics-8.0.220-py3-none-any.whl.metadata
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 646.0/646.0 kB 13.5 MB/s eta 0:00:0000:01
# ...
#   Obtaining dependency information for roboflow from https://files.pythonhosted.org/packages/7e/a2/f1172337cf3e5b678c80ece8981de92f9ee0c924fe36084f577e6ca34795/roboflow-1.1.10-py3-none-any.whl.metadata
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 4.6 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 4.0 MB/s eta 0:00:00
# ...
#   Obtaining dependency information for opencv-python-headless==4.8.0.74 from https://files.pythonhosted.org/packages/76/02/f128517f3ade4bb5f71e2afd8461dba70e3f466ce745fa1fd1fade9ad1b7/opencv_python_headless-4.8.0.74-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
# ...

# %%
import wandb
from roboflow import Roboflow
from ultralytics import YOLO

# %%
# !pip freeze > requirements.txt

# %%
rf = Roboflow(api_key="MDlKcTc8S013W8Cd9uoO")
project = rf.workspace("cchegeu").project("russian-signs")
dataset = project.version(15).download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.0.220, to fix: `pip install ultralytics==8.0.196`
# ...
# Extracting Dataset Version Zip to Russian-signs-15 in yolov8:: 100%|██████████| 6004/6004 [00:01<00:00, 3810.42it/s]

# %%
wandb.init(
    # set the wandb project where this run will be logged
    # track hyperparameters and run metadata
    config={
    "architecture": "YOLO8n"
    }
)
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#   ·······························
# wandb: ERROR API key must be 40 characters long, yours was 31
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#   ········································
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>/kaggle/working/wandb/run-20231129_190623-91q1iyru</code>
# ...

# %%
model = YOLO('yolov8n.yaml')
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
# ...

# %% [markdown]
# Снизу в data надо указать путь yaml файла для дальнейшего обучения модели.

# %%
model.train(data='/kaggle/input/dadasda/data.yaml', epochs=50, batch=64, mosaic=1)
# Out:
# Ultralytics YOLOv8.0.220 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla T4, 15110MiB)
# ...

# %%
metrics = model.val(split="test")
# Out:
# Ultralytics YOLOv8.0.220 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla T4, 15110MiB)
# YOLOv8n summary (fused): 168 layers, 3015398 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /kaggle/working/Russian-signs-15/test/labels... 306 images, 2 backgrounds, 0 corrupt: 100%|██████████| 306/306 [00:00<00:00, 1007.04it/s]
# val: New cache created: /kaggle/working/Russian-signs-15/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:10<00:00,  2.19s/it]
#                    all        306       1511      0.537      0.161      0.179      0.111
#               100Limit        306          1          0          0          0          0
#              1sideRoad        306         25      0.329       0.24      0.235      0.163
#         1sideRoadRight        306          7          1          0      0.158     0.0903
#                20Limit        306          2          0          0    0.00498    0.00249
# ...
